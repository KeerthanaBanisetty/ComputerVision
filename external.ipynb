# %%
import cv2
import numpy as np
image = cv2.imread('image.png')
image = cv2.resize(image,(300,200))
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY )
binary =cv2.Canny(gray,100,200)
contours,hierarchy = cv2.findContours(binary,
cv2.RETR_EXTERNAL ,cv2.CHAIN_APPROX_SIMPLE)
output_image = image.copy()
for i,contour in enumerate(contours) :
    perimeter =cv2.arcLength(contour ,True)
    print(f"Contour {i+1}: Perimeter = {perimeter}")
    cv2.drawContours(output_image, [contour], -1, (0, 255, 0), 2)
    x, y, w, h = cv2.boundingRect(contour)
    cv2.putText(output_image, f"{perimeter:.2f}", (x, y - 10),
cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)
cv2.imshow('Contours with Perimeters', output_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Contour 1: Perimeter = 16.485281229019165
# Contour 2: Perimeter = 11.656854152679443
# Contour 3: Perimeter = 6.828427076339722
# Contour 4: Perimeter = 15.656854152679443
# Contour 5: Perimeter = 35.31370830535889
# Contour 6: Perimeter = 25.55634891986847
# Contour 7: Perimeter = 36.38477599620819
# Contour 8: Perimeter = 2.0
# Contour 9: Perimeter = 22.485281229019165
# Contour 10: Perimeter = 26.0
# Contour 11: Perimeter = 4.828427076339722
# Contour 12: Perimeter = 81.8406195640564
# Contour 13: Perimeter = 121.29646337032318
# Contour 14: Perimeter = 105.8406195640564
# Contour 15: Perimeter = 138.6690467596054
# Contour 16: Perimeter = 0.0
# Contour 17: Perimeter = 34.3847758769989
# Contour 18: Perimeter = 38.97056245803833
# Contour 19: Perimeter = 0.0
# Contour 20: Perimeter = 30.14213538169861
# Contour 21: Perimeter = 197.82337474822998
# Contour 22: Perimeter = 74.18376553058624
# Contour 23: Perimeter = 4.0
# Contour 24: Perimeter = 3.414213538169861
# Contour 25: Perimeter = 8.828427076339722
# Contour 26: Perimeter = 7.656854152679443
# Contour 27: Perimeter = 56.041630148887634
# Contour 28: Perimeter = 0.0
# Contour 29: Perimeter = 4.828427076339722
# Contour 30: Perimeter = 81.25483298301697
# Contour 31: Perimeter = 20.14213538169861
# Contour 32: Perimeter = 0.0
# Contour 33: Perimeter = 54.426406502723694
# Contour 34: Perimeter = 293.60511791706085
# Contour 35: Perimeter = 2.0
# Contour 36: Perimeter = 164.95331740379333
# Contour 37: Perimeter = 38.28427076339722
# Contour 38: Perimeter = 52.627416491508484
# Contour 39: Perimeter = 49.21320307254791
# Contour 40: Perimeter = 2.8284270763397217
# Contour 41: Perimeter = 22.485281229019165
# Contour 42: Perimeter = 21.071067690849304
# Contour 43: Perimeter = 10.0
# Contour 44: Perimeter = 24.38477611541748
# Contour 45: Perimeter = 18.727921724319458
# Contour 46: Perimeter = 0.0
# Contour 47: Perimeter = 34.97056245803833
# Contour 48: Perimeter = 23.656854152679443
# Contour 49: Perimeter = 28.14213538169861
# Contour 50: Perimeter = 6.828427076339722
# Contour 51: Perimeter = 167.74011433124542
# Contour 52: Perimeter = 23.313708305358887
# Contour 53: Perimeter = 15.313708305358887
# Contour 54: Perimeter = 0.0
# Contour 55: Perimeter = 297.2964632511139
# Contour 56: Perimeter = 33.21320295333862
# Contour 57: Perimeter = 64.6274163722992
# Contour 58: Perimeter = 17.899494767189026
# Contour 59: Perimeter = 25.313708305358887
# Contour 60: Perimeter = 85.35533845424652
# Contour 61: Perimeter = 128.2253955602646
# Contour 62: Perimeter = 3.414213538169861
# Contour 63: Perimeter = 91.84061968326569
# Contour 64: Perimeter = 18.727921724319458
# Contour 65: Perimeter = 13.899494767189026
# Contour 66: Perimeter = 0.0
# Contour 67: Perimeter = 158.56854152679443
# Contour 68: Perimeter = 101.49747359752655
# Contour 69: Perimeter = 13.656854152679443
# Contour 70: Perimeter = 88.56854140758514
# Contour 71: Perimeter = 202.61017167568207
# Contour 72: Perimeter = 212.55129635334015
# Contour 73: Perimeter = 115.8406195640564
# Contour 74: Perimeter = 109.25483322143555
# Contour 75: Perimeter = 182.16652035713196
# Contour 76: Perimeter = 4.0
# Contour 77: Perimeter = 0.0
# Contour 78: Perimeter = 109.15432798862457
# Contour 79: Perimeter = 6.828427076339722
# Contour 80: Perimeter = 34.041629910469055
# Contour 81: Perimeter = 4.0
# Contour 82: Perimeter = 82.18376541137695
# Contour 83: Perimeter = 32.041630029678345
# Contour 84: Perimeter = 0.0
# Contour 85: Perimeter = 0.0
# Contour 86: Perimeter = 0.0
# Contour 87: Perimeter = 8.828427076339722
# Contour 88: Perimeter = 0.0
# Contour 89: Perimeter = 11.41421353816986
# Contour 90: Perimeter = 114.42640614509583
# Contour 91: Perimeter = 76.18376529216766
# Contour 92: Perimeter = 4.828427076339722
# Contour 93: Perimeter = 0.0
# Contour 94: Perimeter = 13.071067690849304
# Contour 95: Perimeter = 2.0
# Contour 96: Perimeter = 6.0
# Contour 97: Perimeter = 47.69848418235779
# Contour 98: Perimeter = 109.63960897922516
# Contour 99: Perimeter = 125.78174412250519
# Contour 100: Perimeter = 2.0
# Contour 101: Perimeter = 12.485281229019165
# Contour 102: Perimeter = 24.97056233882904
# Contour 103: Perimeter = 151.19595789909363
# Contour 104: Perimeter = 4.828427076339722
# Contour 105: Perimeter = 667.4112499952316
# Contour 106: Perimeter = 793.293498635292
# Contour 107: Perimeter = 33.899494767189026
# Contour 108: Perimeter = 24.14213526248932
# Contour 109: Perimeter = 4.828427076339722
# Contour 110: Perimeter = 23.899494767189026
# Contour 111: Perimeter = 37.55634891986847
# Contour 112: Perimeter = 2.0
# Contour 113: Perimeter = 13.071067690849304
# Contour 114: Perimeter = 0.0
# Contour 115: Perimeter = 18.72792160511017
# Contour 116: Perimeter = 29.313708305358887
# Contour 117: Perimeter = 18.242640614509583
# Contour 118: Perimeter = 4.0
# Contour 119: Perimeter = 153.4385987520218
# Contour 120: Perimeter = 12.242640614509583
# Contour 121: Perimeter = 5.414213538169861
# Contour 122: Perimeter = 101.49747383594513
# Contour 123: Perimeter = 228.45079123973846
# Contour 124: Perimeter = 69.11269783973694
# Contour 125: Perimeter = 16.485281229019165
# Contour 126: Perimeter = 5.414213538169861
# Contour 127: Perimeter = 2.0
# Contour 128: Perimeter = 0.0
# Contour 129: Perimeter = 2.8284270763397217
# Contour 130: Perimeter = 11.071067690849304
# Contour 131: Perimeter = 312.9777022600174
# Contour 132: Perimeter = 60.28427076339722
# Contour 133: Perimeter = 0.0
# Contour 134: Perimeter = 5.414213538169861
# Contour 135: Perimeter = 222.69343185424805
# Contour 136: Perimeter = 6.828427076339722
# Contour 137: Perimeter = 52.38477599620819
# Contour 138: Perimeter = 73.79898953437805
# Contour 139: Perimeter = 37.1126983165741
# Contour 140: Perimeter = 7.414213538169861
# Contour 141: Perimeter = 6.828427076339722
# Contour 142: Perimeter = 3.414213538169861
# Contour 143: Perimeter = 24.14213538169861
# Contour 144: Perimeter = 2.0
# Contour 145: Perimeter = 12.485281109809875
# Contour 146: Perimeter = 6.0
# Contour 147: Perimeter = 108.81118214130402
# Contour 148: Perimeter = 43.21320307254791
# Contour 149: Perimeter = 57.69848430156708
# Contour 150: Perimeter = 0.0
# Contour 151: Perimeter = 2.0
# Contour 152: Perimeter = 28.14213538169861
# Contour 153: Perimeter = 0.0
# Contour 154: Perimeter = 126.3675308227539
# Contour 155: Perimeter = 43.69848418235779
# Contour 156: Perimeter = 130.08326029777527
# Contour 157: Perimeter = 20.485281229019165
# Contour 158: Perimeter = 128.71067690849304
# Contour 159: Perimeter = 72.52691125869751
# Contour 160: Perimeter = 21.899494647979736
# Contour 161: Perimeter = 39.21320295333862
# Contour 162: Perimeter = 2.0
# Contour 163: Perimeter = 2.0
# Contour 164: Perimeter = 34.870057344436646
# Contour 165: Perimeter = 4.0
# Contour 166: Perimeter = 11.071067690849304
# Contour 167: Perimeter = 6.2426406145095825
# Contour 168: Perimeter = 0.0
# Contour 169: Perimeter = 0.0
# Contour 170: Perimeter = 29.455844283103943
# Contour 171: Perimeter = 24.627416610717773
# Contour 172: Perimeter = 2.8284270763397217
# Contour 173: Perimeter = 50.42640709877014
# Contour 174: Perimeter = 99.49747359752655
# Contour 175: Perimeter = 74.28427076339722
# Contour 176: Perimeter = 8.485280990600586
# Contour 177: Perimeter = 15.313708305358887
# Contour 178: Perimeter = 2119.204307079315
# Contour 179: Perimeter = 750.2569210529327
